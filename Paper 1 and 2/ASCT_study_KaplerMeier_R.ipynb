# %% [markdown]
# In this notebook, I use R to create, plot and assess Kaplan Meier curves that are generated from the dataset.

# %% [markdown]
# Import necessary libraries

# %%
library("survival")
library("survminer")

print("complete")
# Out:
# Loading required package: ggplot2
# Loading required package: ggpubr
# [1] "complete"

# %% [markdown]
# Import the data.
#
# I assign the dataset I wish to analyze to the variable: 'dataset'

# %%
ASCT_PFS_HighRisk_NumOfMainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_NumOfMainten_Dataset.csv')
ASCT_PFS_HighRisk_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_MaintenVsNone_Dataset.csv' )
ASCT_PFS_LowRisk_NumOfMainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_LowRisk_NumOfMainten_Dataset.csv')
ASCT_PFS_LowRisk_MaintenVsNone_Dataset <- read.csv(file= '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_LowRisk_MaintenVsNone_Dataset.csv')

#ASCT_OS_HighRisk_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_Dataset.csv')
#ASCT_OS_LowRisk_Dataset <- read.csv(file= '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_LowRisk_Dataset.csv')
ASCT_OS_Risk_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_Risk_Dataset.csv')
ASCT_PFS_Risk_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_Risk_Dataset.csv')
ASCT_PFS2_Risk_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS2_Risk_Dataset.csv' )

ASCT_OS_HighRisk_NumOfMainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_NumOfMainten_Dataset.csv')
ASCT_OS_HighRisk_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_MaintenVsNone_Dataset.csv')
ASCT_OS_LowRisk_NumOfMainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_LowRisk_NumOfMainten_Dataset.csv')
ASCT_OS_LowRisk_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_LowRisk_MaintenVsNone_Dataset.csv')

ASCT_OS_HighRisk_LiMaintenDose_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_LiMaintenDose_Dataset.csv')
ASCT_OS_LowRisk_LiMaintenDose_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_LowRisk_LiMaintenDose_Dataset.csv')

ASCT_PFS2_HighRisk_NumOfMainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS2_HighRisk_NumOfMainten_Dataset.csv')
ASCT_PFS2_HighRisk_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS2_HighRisk_MaintenVsNone_Dataset.csv')
ASCT_PFS2_LowRisk_NumOfMainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS2_LowRisk_NumOfMainten_Dataset.csv')
ASCT_PFS2_LowRisk_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS2_LowRisk_MaintenVsNone_Dataset.csv')

ASCT_PFS_HighRisk_SingVsTan <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_SingVsTan.csv')
ASCT_PFS_LowRisk_SingVsTan <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_LowRisk_SingVsTan.csv')

ASCT_OS_HighRisk_SingVsTan <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_SingVsTan.csv')
ASCT_OS_LowRisk_SingVsTan <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_LowRisk_SingVsTan.csv')

#extra ones Shona asked for: 
ASCT_PFS_HighRisk_SingleTrans_MaintenVsNone_Dataset <-read.csv(file = "/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_SingleTrans_MaintenVsNone_Dataset.csv")
ASCT_PFS_HighRisk_TandemTrans_MaintenVsNone_Dataset <-read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_TandemTrans_MaintenVsNone_Dataset.csv')
ASCT_OS_HighRisk_SingleTrans_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_SingleTrans_MaintenVsNone_Dataset.csv')
ASCT_OS_HighRisk_TandemTrans_MaintenVsNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_TandemTrans_MaintenVsNone_Dataset.csv')

ASCT_PFS_HighRisk_NoMainten_SingVsTan_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_NoMainten_SingVsTan_Dataset.csv')
ASCT_PFS_HighRisk_Mainten_SingVsTan_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_Mainten_SingVsTan_Dataset.csv')
ASCT_OS_HighRisk_NoMainten_SingVsTan_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_NoMainten_SingVsTan_Dataset.csv')
ASCT_OS_HighRisk_Mainten_SingVsTan_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_HighRisk_Mainten_SingVsTan_Dataset.csv')

#Extra ones Mina asked for 

ASCT_PFS_MaintenVSNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_MaintenVSNone_Dataset.csv')
ASCT_OS_MaintenVSNone_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_OS_MaintenVSNone_Dataset.csv')

# 2 extra curves to explore significance between 1 vs. 2 maintenance for PFS and PFS2 high risk populations. 

ASCT_PFS_HighRisk_1vs2Mainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS_HighRisk_1vs2Mainten_Dataset.csv')
ASCT_PFS2_HighRisk_1vs2Mainten_Dataset <- read.csv(file = '/Users/anthonyquint/Desktop/LHSC_Work_Folder/Mina/MM_ACST_Study/Prepared_data_for_R_analysis/ASCT_PFS2_HighRisk_1vs2Mainten_Dataset.csv')


dataset <- ASCT_OS_MaintenVSNone_Dataset

#head(dataset)

# %% [markdown]
# Fit a kapler meier curve.
#
# I uncomment out the fit variable which fits the dataset I am analyzing.

# %%
#fit <- survfit(Surv(Progression.Free.Surivival..PFS...days., PFS_Status..1.censored.2.event.) ~ Number_of_Maintenance_Drugs, data = dataset)
#fit <- survfit(Surv(Overall.Survival..OS...days., OS_Status..1...censored..2...event.)~ At_Risk..Y.N..for.Anthony, data = dataset)
#fit <- survfit(Surv(Progression.Free.Surivival..PFS...days., PFS_Status..1.censored.2.event.) ~ At_Risk..Y.N..for.Anthony, data = dataset)
#fit <- survfit(Surv(Progression.Free.Survival.2..PFS2...days., PFS2_Status..1...censored..2...event.) ~ At_Risk..Y.N..for.Anthony, data = dataset)

fit <- survfit(Surv(Overall.Survival..OS...days., OS_Status..1...censored..2...event.) ~ Number_of_Maintenance_Drugs, data = dataset)
#fit <- survfit(Surv(Overall.Survival..OS...days., OS_Status..1...censored..2...event.) ~ lenalidomide.maintenance.dose...1..discontinued..2...reduced..3...same., data = dataset)
#fit <- survfit(Surv(Progression.Free.Survival.2..PFS2...days., PFS2_Status..1...censored..2...event.) ~ Number_of_Maintenance_Drugs, data = dataset)
#fit <- survfit(Surv(Progression.Free.Surivival..PFS...days., PFS_Status..1.censored.2.event.) ~ TANDEM, data = dataset)
#fit <- survfit(Surv(Overall.Survival..OS...days., OS_Status..1...censored..2...event.)~ TANDEM, data = dataset)

print(fit)
summary(fit)
summary(fit)$table
# Out:
# Call: survfit(formula = Surv(Overall.Survival..OS...days., OS_Status..1...censored..2...event.) ~
#     Number_of_Maintenance_Drugs, data = dataset)
#
#    5 observations deleted due to missingness
#                                 n events median 0.95LCL 0.95UCL
# Number_of_Maintenance_Drugs=0 101     17     NA    4162      NA
# Number_of_Maintenance_Drugs=1  52      7     NA    1853      NA
# Call: survfit(formula = Surv(Overall.Survival..OS...days., OS_Status..1...censored..2...event.) ~
#     Number_of_Maintenance_Drugs, data = dataset)
#
# 5 observations deleted due to missingness
#                 Number_of_Maintenance_Drugs=0
#  time n.risk n.event survival std.err lower 95% CI upper 95% CI
#   327     80       1    0.988  0.0124        0.963        1.000
#   337     79       1    0.975  0.0175        0.941        1.000
#   460     78       1    0.963  0.0212        0.922        1.000
#   523     75       1    0.950  0.0245        0.903        0.999
# ...

# %% [markdown]
# Plot a kalper meier curve

# %%
ggsurvplot(
   fit,                     # survfit object with calculated statistics.
   pval = TRUE,             # show p-value of log-rank test.
   conf.int = TRUE,         # show confidence intervals for 
                            # point estimaes of survival curves.
   conf.int.style = "step",  # customize style of confidence intervals
   xlab = "Time in days",   # customize X axis label.
   #break.time.by = 200,     # break X axis in time intervals by 200.
   ggtheme = theme_light(), # customize plot and risk table with a theme.
   risk.table = "abs_pct",  # absolute number and percentage at risk.
  risk.table.y.text.col = T,# colour risk table text annotations.
  risk.table.y.text = FALSE,# show bars instead of names in text annotations
                            # in legend of risk table.
  ncensor.plot = TRUE,      # plot the number of censored subjects at time t
  surv.median.line = "hv",  # add the median survival pointer.
  #legend.labs = 
   # c("Female", "Male"),    # change legend labels.
  #palette = 
   # c("#E7B800", "#2E9FDF") # custom color palettes.
)
# Out:
# Warning message in .add_surv_median(p, fit, type = surv.median.line, fun = fun, :
# “Median survival not reached.”
# plot without title

# %% [markdown]
# Log-Rank test to establish significance

# %%
#surv_diff <- survdiff(Surv(Progression.Free.Surivival..PFS...days.,PFS_Status..1.censored.2.event.) ~ Number_of_Maintenance_Drugs, data = dataset)
#surv_diff
